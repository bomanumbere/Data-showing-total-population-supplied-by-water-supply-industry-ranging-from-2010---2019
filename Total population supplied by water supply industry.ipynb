# %%
import matplotlib
import pandas as pd
import seaborn as sns
import math
import statistics
import numpy as np

sns.set(color_codes=True)
watersupply = pd.read_csv('water.csv')
watersupply.info()
watersupply
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  42 non-null     object
#  1   Year             42 non-null     int64
#  2   Value            42 non-null     float64
#  3   Value Footnotes  10 non-null     float64
#  4   Unit             42 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.8+ KB
#                 Country or Area  Year      Value  Value Footnotes Unit
# 0                       Algeria  2015  98.000000              NaN    %
# 1                       Algeria  2014  98.000000              NaN    %
# 2                       Algeria  2013  98.000000              NaN    %
# 3                       Algeria  2012  98.000000              NaN    %
# 4                       Algeria  2011  96.500000              NaN    %
# 5                       Algeria  2010  96.000000              NaN    %
# 6                        Angola  2011  15.300000              NaN    %
# 7                    Cabo Verde  2015  83.400002              1.0    %
# 8                    Cabo Verde  2014  83.699997              1.0    %
# 9                    Cabo Verde  2013  84.400002              1.0    %
# 10                   Cabo Verde  2012  85.400002              1.0    %
# 11                   Cabo Verde  2010  83.599998              1.0    %
# 12                        Egypt  2015  98.000000              NaN    %
# 13                    Mauritius  2015  99.699997              NaN    %
# 14                    Mauritius  2014  99.699997              NaN    %
# 15                    Mauritius  2013  99.699997              NaN    %
# 16                    Mauritius  2012  99.699997              NaN    %
# 17                    Mauritius  2011  99.699997              NaN    %
# 18                    Mauritius  2010  99.500000              NaN    %
# 19                      Morocco  2014  83.000000              2.0    %
# 20                      Morocco  2013  81.500000              2.0    %
# 21                      Morocco  2012  80.199997              2.0    %
# 22                      Morocco  2011  79.500000              2.0    %
# 23                      Morocco  2010  77.500000              2.0    %
# 24                      Nigeria  2010  56.000000              NaN    %
# 25                       Rwanda  2010  74.199997              NaN    %
# 26                 Saudi Arabia  2013  98.000000              NaN    %
# 27                 Saudi Arabia  2012  98.000000              NaN    %
# 28                 Saudi Arabia  2011  97.000000              NaN    %
# 29                 Saudi Arabia  2010  96.000000              NaN    %
# 30                 South Africa  2012  93.800003              NaN    %
# 31                 South Africa  2011  93.500000              NaN    %
# 32                 South Africa  2010  92.699997              NaN    %
# 33                        Sudan  2011  60.500000              NaN    %
# 34                        Sudan  2010  60.000000              NaN    %
# 35                      Tunisia  2015  97.599998              NaN    %
# 36                      Tunisia  2014  97.500000              NaN    %
# 37                      Tunisia  2013  97.500000              NaN    %
# 38                      Tunisia  2012  97.300003              NaN    %
# 39                      Tunisia  2011  97.900002              NaN    %
# 40                      Tunisia  2010  97.800003              NaN    %
# 41  United Republic of Tanzania  2013  55.599998              NaN    %

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
water = pd.read_csv('water.csv')
 
plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*60+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])


 
    

plt.legend(loc='upper right')
sns.barplot(water['Country or Area'],water['Value'],  water['Year'])
# Out:
# No handles with labels found to put in legend.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country or Area', ylabel='Value'>

# %%
plt.figure(figsize=(8,10))

def interquartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return q3 - q1

def quartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return (q3 - q1)/2

def _range(sample):
    return sample.max() - sample.min()

def create_plot(fn, label):
    ls = []
    for year in range(2010,2019):
            ls.append(fn(water[water['Year'] == year]['Value']))
              
    plt.plot(range(2010,2019), ls, label=label)
    plt.title('Water Supply')
    plt.ylabel('Value')
    plt.xlabel('Year')
    
create_plot(statistics.mean, 'Mean')
create_plot(statistics.variance, 'Variance')
create_plot(statistics.stdev, 'Standard Deviation')
create_plot(interquartile_range, 'Interquartile Range')
create_plot(quartile_range, 'Quartile Range')
create_plot(_range, 'Range')

plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-49-af4e157c5d4f> in <module>
#      22     plt.xlabel('Year')
#      23
# ---> 24 create_plot(statistics.mean, 'Mean')
#      25 create_plot(statistics.variance, 'Variance')
#      26 create_plot(statistics.stdev, 'Standard Deviation')
#
# <ipython-input-49-af4e157c5d4f> in create_plot(fn, label)
#      15     ls = []
#      16     for year in range(2010,2019):
# ---> 17             ls.append(fn(water[water['Year'] == year]['Value']))
#      18
#      19     plt.plot(range(2010,2019), ls, label=label)
#
# C:\ProgramData\Anaconda3\lib\statistics.py in mean(data)
#     313     n = len(data)
#     314     if n < 1:
# --> 315         raise StatisticsError('mean requires at least one data point')
#     316     T, total, count = _sum(data)
#     317     assert count == n
#
# StatisticsError: mean requires at least one data point

# %%
plt.figure(figsize=(8,10))

def interquartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return q3 - q1

def quartile_range(sample):
    q3, q1 = np.percentile(sample, [75 ,25])
    return (q3 - q1)/2

def _range(sample):
    return sample.max() - sample.min()

def create_plot(fn, label):
    ls = []
    for year in range(2010,2019):
            ls.append(fn(water[water['Year'] == year]['Value']))
              
    plt.plot(range(2010,2019), ls, label=label)
    plt.title('Water Supply')
    plt.ylabel('Value')
    plt.xlabel('Year')
    
create_plot(statistics.mean, 'Mean')
create_plot(statistics.variance, 'Variance')
create_plot(statistics.stdev, 'Standard Deviation')
create_plot(interquartile_range, 'Interquartile Range')
create_plot(quartile_range, 'Quartile Range')
create_plot(_range, 'Range')

plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-41-af4e157c5d4f> in <module>
#      22     plt.xlabel('Year')
#      23
# ---> 24 create_plot(statistics.mean, 'Mean')
#      25 create_plot(statistics.variance, 'Variance')
#      26 create_plot(statistics.stdev, 'Standard Deviation')
#
# <ipython-input-41-af4e157c5d4f> in create_plot(fn, label)
#      15     ls = []
#      16     for year in range(2010,2019):
# ---> 17             ls.append(fn(water[water['Year'] == year]['Value']))
#      18
#      19     plt.plot(range(2010,2019), ls, label=label)
#
# C:\ProgramData\Anaconda3\lib\statistics.py in mean(data)
#     313     n = len(data)
#     314     if n < 1:
# --> 315         raise StatisticsError('mean requires at least one data point')
#     316     T, total, count = _sum(data)
#     317     assert count == n
#
# StatisticsError: mean requires at least one data point
